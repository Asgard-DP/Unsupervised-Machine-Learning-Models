# %%
# Import the modules
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
# Generate synthetic clusters

x, y = make_blobs(
    centers=3,
    random_state=1
)

# random state 1 recreates the cluster the exact same , keeps x and y the same 

# center is the number of groups/patterns 
#Random state assigns the code to the designated value for code repoducability

# %%
# Visualizing both classes



plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
# Generate synthetic clusters

X, y = make_blobs(
    centers=5,
    random_state=10
)

# %%
# Visualizing both classes

plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
# Generate synthetic clusters
X, y = make_blobs(
     centers=4,
     random_state=3
 )

# %%
# Visualizing both classes
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
# Generate synthetic cluster

X, y = make_blobs(
    centers=2,
    random_state=11
)

# %%
# Visualizing both classes
plt.scatter(X[:, 0], X[:, 1], c=y)
